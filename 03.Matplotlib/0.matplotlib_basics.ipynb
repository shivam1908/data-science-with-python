# %% [markdown]
# # Matplotlib

# %% [markdown]
# ### Basic Plot functions
# [pyplot.plot()](#)

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
import numpy as np

# %%
x =np.arange(0,10)

# %%
y=2*x

# %% [markdown]
# .plot()

# %%
plt.plot(x,y)
#plt.show() -- for py script but not needed for jupyter notebook
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.xlim(0,10)
plt.ylim(0,20)
plt.title('x versus y')
plt.savefig('myfirstplot.png')
